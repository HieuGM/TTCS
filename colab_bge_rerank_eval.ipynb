# %% [markdown]
# # BGE Rerank + Retrieval Evaluation
#
# Upload `candidates.jsonl`, `grounth_truth_record_id.csv`, and `colab_bge_rerank_eval.py`, then run all cells on a Colab GPU runtime.

# %%
# !pip install -U FlagEmbedding

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !python colab_bge_rerank_eval.py \
  --candidates candidates.jsonl \
  --ground-truth grounth_truth_record_id.csv \
  --output-dir rerank_eval_output

# %%
import pandas as pd
pd.read_csv('rerank_eval_output/rerank_eval_summary.csv')

# %%
# !zip -r rerank_eval_output.zip rerank_eval_output
files.download('rerank_eval_output.zip')
